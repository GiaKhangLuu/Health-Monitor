# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
import sys
import glob
from PIL import Image
import shutil

# %%
src_img_dir = '/Users/giakhang/Desktop/checkme/'

# %%
img_paths = glob.glob(os.path.join(src_img_dir, 'images/*'))

# %%
img_paths
# Out:
# ['/Users/giakhang/Desktop/checkme/images/IMG_9947_596.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_227.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_179.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9928_37.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_20221014_135604.jpg',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_420.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9928_205.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9926_27.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_636.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_187.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9928_173.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_540.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9924_180.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_556.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9928_165.png',
#  '/Users/giakhang/Desktop/checkme/images/IMG_9947_620.png',
# ...

# %%
img = cv2.imread(img_paths[0])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
Image.fromarray(img).save('./test.jpg')

# %%
img = cv2.imread('./test.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img_path = img_paths[0]
img_ext = img_path.split('.')[-1]
label_path = img_path.replace('images', 'labels').replace(img_ext, 'txt')

# %%
img_path
# Out:
# '/Users/giakhang/Desktop/checkme/images/IMG_9947_596.png'

# %%
label_path
# Out:
# '/Users/giakhang/Desktop/checkme/labels/IMG_9947_596.txt'

# %%
def show_gt_img(img_path, label_path):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_h, img_w, _ = img.shape
    x_list, y_list = [], []
    polygon_list = []
    
    with open(label_path, 'r') as f:
        for line in f:
            _, x_center_norm, y_center_norm, w_norm, h_norm = map(float, line.split(' '))
            x1_norm, y1_norm = x_center_norm - (w_norm / 2), y_center_norm - (h_norm / 2)
            x2_norm, y2_norm = x1_norm + w_norm, y1_norm + h_norm
            x1, y1 = x1_norm * img_w, y1_norm * img_h
            x2, y2 = x2_norm * img_w, y2_norm * img_h
            x_list += [x1, x2]
            y_list += [y1, y2]
            #img = cv2.rectangle(img, pt1, pt2, (0, 255, 0))
            
    #x_list = sorted(x_list)
    #y_list = sorted(y_list)
    
    sorted_x = sorted(x_list)
    sorted_y = sorted(y_list)
    x_old_loc = [x_list.index(x) for x in sorted_x]
    y_old_loc = [y_list.index(y) for y in sorted_y]
    print(x_list)
    print(y_list)
    print(x_old_loc)
    print(y_old_loc)
    
    threshold = 50
    
    while len(sorted_x) != 0:
        
    
    
    
    #plt.imshow(img)
    #plt.show()

# %%
show_gt_img(img_path, label_path)
# Out:
# [165.9999075, 191.99992250000003, 190.00011475, 221.00010525000002, 333.99980075, 361.99977924999996, 91.9997895, 116.9998005, 66.00006375, 95.00004625000001, 307.99978575, 335.99976425, 115.99981875000002, 144.99980125000002]
# [74.99992499999999, 141.000015, 75.0000225, 138.9999975, 70.00012499999998, 130.00006499999998, 78.99995999999999, 146.00001, 78.99995999999999, 146.00001, 71.00008499999998, 131.000025, 78.0, 145.00005]
# [8, 6, 9, 12, 7, 13, 0, 2, 1, 3, 10, 4, 11, 5]
# [4, 10, 0, 2, 12, 6, 6, 5, 11, 3, 1, 13, 7, 7]

# %%
x = [1, 2, 3, 4, 5, 5]

# %%
x.index(5)
# Out:
# 4

# %%
x.sort()

# %%
x
# Out:
# [1, 2, 3, 4, 5, 5]

# %%
x = 10
while x != 0:
    x -=1
    print(x)
# Out:
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1
# 0

# %%
x = [1, 2, 3]

# %%
x.pop(0)
# Out:
# 1

# %%
x
# Out:
# [2, 3]

# %%
x.pop(0)
# Out:
# 2

# %%
x.pop(0)
# Out:
# 3
